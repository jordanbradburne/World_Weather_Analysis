# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
vacation_df
# Out:
#      City_ID            City Country  Max Temp      Lat       Lng  \
# 0          0         Buluang      PH     82.22  13.3068  123.3425
# 1          1        Tomatlan      MX     86.81  19.9333 -105.2500
# 2          6  Guerrero Negro      MX     82.81  27.9769 -114.0611
# 3          7         Matoury      GF     83.01   4.8483  -52.3317
# 4         11          Avarua      CK     75.25 -21.2078 -159.7750
# ..       ...             ...     ...       ...      ...       ...
# 241      663        Yinchuan      CN     75.70  38.4681  106.2731
# 242      665    Isla Mujeres      MX     87.17  21.2311  -86.7310
# 243      666          Sokoni      TZ     75.36  -6.4333   39.5500
# 244      668         Veraval      IN     81.25  20.9000   70.3667
# 245      671    Luis Correia      BR     77.92  -2.8792  -41.6669
#
#     Current Description                                 Hotel Name
# 0            light rain                          Enon Beach Resort
# 1            few clouds                                 El Salvial
# 2             clear sky               Casa Laguna, Bed & Breakfast
# 3             clear sky                          Hôtel La Marmotte
# 4         moderate rain                               Paradise Inn
# ..                  ...                                        ...
# 241       broken clouds  JJ Inns - Yinchuan New Moon Square Branch
# 242           clear sky                 Hotel La Joya Isla Mujeres
# 243          few clouds                        Ujamaa Beach Resort
# 244     overcast clouds                          Lords Inn Somnath
# 245     overcast clouds                            Hotel Amarração
#
# [246 rows x 8 columns]

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations =vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

my_itenary =  vacation_df[vacation_df["Country"] == "BR"]
my_itenary.reset_index(drop=True,inplace=True)
my_itenary

start_city = "Jacareacanga"
end_city = "Jacareacanga"
city1 = "Touros"
city2 = "Sitio Novo Do Tocantins"
city3 = "Estreito"

vacation_start = vacation_df.loc[vacation_df["City"] == start_city]
vacation_end = vacation_df.loc[vacation_df["City"] == end_city]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == city1]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == city2] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == city3]

my_itenary
# Out:
#     City_ID                       City Country  Max Temp      Lat      Lng  \
# 0       102               Jacareacanga      BR     83.14  -6.2222 -57.7528
# 1       108                     Touros      BR     79.70  -5.1989 -35.4608
# 2       221    Sitio Novo Do Tocantins      BR     85.93  -5.5183 -47.4611
# 3       261                   Araguacu      BR     83.44 -12.9306 -49.8264
# 4       279  Santa Isabel Do Rio Negro      BR     75.63  -0.4139 -65.0192
# 5       299                    Itarema      BR     79.00  -2.9248 -39.9167
# 6       317                    Camocim      BR     78.24  -2.9022 -40.8411
# 7       345                   Estreito      BR     86.16  -5.7833 -43.2500
# 8       427                  Boa Vista      BR     76.98   2.8197 -60.6733
# 9       533                 Rio Branco      BR     79.41  -9.9747 -67.8100
# 10      567                   Itaituba      BR     83.12  -4.2761 -55.9836
# 11      652                Paragominas      BR     75.92  -2.9667 -47.4833
# 12      660                   Paracuru      BR     80.62  -3.4100 -39.0306
# 13      671               Luis Correia      BR     77.92  -2.8792 -41.6669
#
#    Current Description                          Hotel Name
# 0     scattered clouds                        Casa do Ian😎
# 1            clear sky                     INN NEW HORIZON
# 2           few clouds                      Imperial Hotel
# 3     scattered clouds                     Hotel Tocantins
# 4      overcast clouds                           Hotel GSA
# 5        broken clouds  Sea Lounge! Bar, Club & Restaurant
# 6      overcast clouds                  Hotel Ilha do Amor
# 7      overcast clouds                                 NaN
# 8        broken clouds                  Aipana Plaza Hotel
# 9            clear sky                    João Paulo Hotel
# 10          light rain                        Hotel Campos
# 11       broken clouds                               INOVA
# 12     overcast clouds                  Hotel Vento Brasil
# 13     overcast clouds                     Hotel Amarração

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start[["Lat", "Lng"]].to_numpy()[0]
end = vacation_end[["Lat", "Lng"]].to_numpy()[0]
stop1 = vacation_stop1[["Lat", "Lng"]].to_numpy()[0]
stop2 = vacation_stop2[["Lat", "Lng"]].to_numpy()[0]
stop3 = vacation_stop3[["Lat", "Lng"]].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure()
travel_route = gmaps.directions_layer(start, end, waypoints=[stop1,stop2,stop3], travel_mode="DRIVING" or "BICYCLING" or "WALKING")
fig.add_layer(travel_route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID                     City Country  Max Temp     Lat      Lng  \
# 0      102             Jacareacanga      BR     83.14 -6.2222 -57.7528
# 1      108                   Touros      BR     79.70 -5.1989 -35.4608
# 2      221  Sitio Novo Do Tocantins      BR     85.93 -5.5183 -47.4611
# 3      345                 Estreito      BR     86.16 -5.7833 -43.2500
#
#   Current Description       Hotel Name
# 0    scattered clouds     Casa do Ian😎
# 1           clear sky  INN NEW HORIZON
# 2          few clouds   Imperial Hotel
# 3     overcast clouds              NaN

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
